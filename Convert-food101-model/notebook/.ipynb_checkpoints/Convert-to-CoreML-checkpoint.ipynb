# %% [markdown]
# ## Import dependencies

# %%
from keras.models import load_model
import coremltools
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Keras model

# %%
model = load_model('../food101-model.hdf5')

# %% [markdown]
# ## Convert Keras model to Core ML model

# %%
coreml_model = coremltools.converters.keras.convert(model, 
                                                    input_names=['image'], 
                                                    output_names=['confidence'], 
                                                    class_labels='labels.txt',
                                                   image_input_names='image', 
                                                    image_scale=2./255, 
                                                    red_bias=-1, 
                                                    green_bias=-1, 
                                                    blue_bias=-1)
# Out:
# 0 : input_1, <keras.engine.topology.InputLayer object at 0x7f9ee7de0650>
# 1 : convolution2d_1, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7de0a50>
# 2 : convolution2d_1__activation__, <keras.layers.core.Activation object at 0x7f9f0ce4d390>
# 3 : batchnormalization_1, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7de0850>
# 4 : convolution2d_2, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7de0b50>
# 5 : convolution2d_2__activation__, <keras.layers.core.Activation object at 0x7f9f0c52b0d0>
# 6 : batchnormalization_2, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7d65f10>
# 7 : convolution2d_3, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7cbe810>
# 8 : convolution2d_3__activation__, <keras.layers.core.Activation object at 0x7f9eb82ca690>
# 9 : batchnormalization_3, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7ce4c10>
# 10 : maxpooling2d_1, <keras.layers.pooling.MaxPooling2D object at 0x7f9ee7c532d0>
# 11 : convolution2d_4, <keras.layers.convolutional.Convolution2D object at 0x7f9ee79df610>
# 12 : convolution2d_4__activation__, <keras.layers.core.Activation object at 0x7f9eb82caf10>
# 13 : batchnormalization_4, <keras.layers.normalization.BatchNormalization object at 0x7f9ee79a4950>
# 14 : convolution2d_5, <keras.layers.convolutional.Convolution2D object at 0x7f9ee794eb90>
# 15 : convolution2d_5__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0990>
# 16 : batchnormalization_5, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7903790>
# 17 : maxpooling2d_2, <keras.layers.pooling.MaxPooling2D object at 0x7f9ee78eff10>
# 18 : convolution2d_9, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7895b50>
# 19 : convolution2d_9__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0a90>
# 20 : batchnormalization_9, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7853e90>
# 21 : convolution2d_7, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7812b10>
# 22 : convolution2d_7__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0090>
# 23 : convolution2d_10, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7836750>
# 24 : convolution2d_10__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0410>
# 25 : batchnormalization_7, <keras.layers.normalization.BatchNormalization object at 0x7f9ee77a5890>
# 26 : batchnormalization_10, <keras.layers.normalization.BatchNormalization object at 0x7f9ee774b750>
# 27 : averagepooling2d_1, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee776e950>
# 28 : convolution2d_6, <keras.layers.convolutional.Convolution2D object at 0x7f9ee76f0710>
# 29 : convolution2d_6__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0150>
# 30 : convolution2d_8, <keras.layers.convolutional.Convolution2D object at 0x7f9ee76b5990>
# 31 : convolution2d_8__activation__, <keras.layers.core.Activation object at 0x7f9ee7de00d0>
# 32 : convolution2d_11, <keras.layers.convolutional.Convolution2D object at 0x7f9ee765ead0>
# 33 : convolution2d_11__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0450>
# 34 : convolution2d_12, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7604950>
# 35 : convolution2d_12__activation__, <keras.layers.core.Activation object at 0x7f9ee7de03d0>
# 36 : batchnormalization_6, <keras.layers.normalization.BatchNormalization object at 0x7f9ee76287d0>
# 37 : batchnormalization_8, <keras.layers.normalization.BatchNormalization object at 0x7f9ee75cd610>
# 38 : batchnormalization_11, <keras.layers.normalization.BatchNormalization object at 0x7f9ee75f3790>
# 39 : batchnormalization_12, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7572550>
# 40 : mixed0, <keras.engine.topology.Merge object at 0x7f9ee7490fd0>
# 41 : convolution2d_16, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7463710>
# 42 : convolution2d_16__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0310>
# 43 : batchnormalization_16, <keras.layers.normalization.BatchNormalization object at 0x7f9ee742d610>
# 44 : convolution2d_14, <keras.layers.convolutional.Convolution2D object at 0x7f9ee73d6a90>
# 45 : convolution2d_14__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0350>
# 46 : convolution2d_17, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7390610>
# 47 : convolution2d_17__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0210>
# 48 : batchnormalization_14, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7301990>
# 49 : batchnormalization_17, <keras.layers.normalization.BatchNormalization object at 0x7f9ee73105d0>
# 50 : averagepooling2d_2, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee72ca0d0>
# 51 : convolution2d_13, <keras.layers.convolutional.Convolution2D object at 0x7f9ee724ced0>
# 52 : convolution2d_13__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0250>
# 53 : convolution2d_15, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7278f50>
# 54 : convolution2d_15__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0190>
# 55 : convolution2d_18, <keras.layers.convolutional.Convolution2D object at 0x7f9ee7239fd0>
# 56 : convolution2d_18__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0390>
# 57 : convolution2d_19, <keras.layers.convolutional.Convolution2D object at 0x7f9ee71cadd0>
# 58 : convolution2d_19__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0110>
# 59 : batchnormalization_13, <keras.layers.normalization.BatchNormalization object at 0x7f9ee71edbd0>
# 60 : batchnormalization_15, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7194b10>
# 61 : batchnormalization_18, <keras.layers.normalization.BatchNormalization object at 0x7f9ee7165f90>
# 62 : batchnormalization_19, <keras.layers.normalization.BatchNormalization object at 0x7f9ee713b850>
# 63 : mixed1, <keras.engine.topology.Merge object at 0x7f9ee7056ed0>
# 64 : convolution2d_23, <keras.layers.convolutional.Convolution2D object at 0x7f9ee702b910>
# 65 : convolution2d_23__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0290>
# 66 : batchnormalization_23, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6ff3810>
# 67 : convolution2d_21, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6f9df50>
# 68 : convolution2d_21__activation__, <keras.layers.core.Activation object at 0x7f9ee7de01d0>
# 69 : convolution2d_24, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6f57810>
# 70 : convolution2d_24__activation__, <keras.layers.core.Activation object at 0x7f9ee7de02d0>
# 71 : batchnormalization_21, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6ec3b90>
# 72 : batchnormalization_24, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6eebb10>
# 73 : averagepooling2d_3, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee6e8f6d0>
# 74 : convolution2d_20, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6e134d0>
# 75 : convolution2d_20__activation__, <keras.layers.core.Activation object at 0x7f9ee7de0050>
# 76 : convolution2d_22, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6dc3510>
# 77 : convolution2d_22__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfce10>
# 78 : convolution2d_25, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6d82ad0>
# 79 : convolution2d_25__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcd50>
# 80 : convolution2d_26, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6da8fd0>
# 81 : convolution2d_26__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcb10>
# 82 : batchnormalization_20, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6db9dd0>
# 83 : batchnormalization_22, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6d5dd10>
# 84 : batchnormalization_25, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6d2ced0>
# 85 : batchnormalization_26, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6c86a50>
# 86 : mixed2, <keras.engine.topology.Merge object at 0x7f9ee6c1efd0>
# 87 : convolution2d_28, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6bf6b10>
# 88 : convolution2d_28__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc410>
# 89 : batchnormalization_28, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6bbba10>
# 90 : convolution2d_29, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6b6af90>
# 91 : convolution2d_29__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfce50>
# 92 : batchnormalization_29, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6b20a10>
# 93 : convolution2d_27, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6a8ef10>
# 94 : convolution2d_27__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc390>
# 95 : convolution2d_30, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6a4bc90>
# 96 : convolution2d_30__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfced0>
# 97 : batchnormalization_27, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6a24b10>
# 98 : batchnormalization_30, <keras.layers.normalization.BatchNormalization object at 0x7f9ee69cb950>
# 99 : maxpooling2d_3, <keras.layers.pooling.MaxPooling2D object at 0x7f9ee6999f90>
# 100 : mixed3, <keras.engine.topology.Merge object at 0x7f9ee6908950>
# 101 : convolution2d_35, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6936690>
# 102 : convolution2d_35__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc210>
# 103 : batchnormalization_35, <keras.layers.normalization.BatchNormalization object at 0x7f9ee68cdad0>
# 104 : convolution2d_36, <keras.layers.convolutional.Convolution2D object at 0x7f9ee68e0f90>
# 105 : convolution2d_36__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc110>
# 106 : batchnormalization_36, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6897910>
# 107 : convolution2d_32, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6805e10>
# 108 : convolution2d_32__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc690>
# 109 : convolution2d_37, <keras.layers.convolutional.Convolution2D object at 0x7f9ee67c1b90>
# 110 : convolution2d_37__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc610>
# 111 : batchnormalization_32, <keras.layers.normalization.BatchNormalization object at 0x7f9ee679da10>
# 112 : batchnormalization_37, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6742850>
# 113 : convolution2d_33, <keras.layers.convolutional.Convolution2D object at 0x7f9ee67669d0>
# 114 : convolution2d_33__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc6d0>
# 115 : convolution2d_38, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6682850>
# 116 : convolution2d_38__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc710>
# 117 : batchnormalization_33, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6658950>
# 118 : batchnormalization_38, <keras.layers.normalization.BatchNormalization object at 0x7f9ee667e510>
# 119 : averagepooling2d_4, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee6622ad0>
# 120 : convolution2d_31, <keras.layers.convolutional.Convolution2D object at 0x7f9ee65a18d0>
# 121 : convolution2d_31__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc050>
# 122 : convolution2d_34, <keras.layers.convolutional.Convolution2D object at 0x7f9ee656d590>
# 123 : convolution2d_34__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcc10>
# 124 : convolution2d_39, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6515890>
# 125 : convolution2d_39__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcf10>
# 126 : convolution2d_40, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6538cd0>
# 127 : convolution2d_40__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc3d0>
# 128 : batchnormalization_31, <keras.layers.normalization.BatchNormalization object at 0x7f9ee64ddad0>
# 129 : batchnormalization_34, <keras.layers.normalization.BatchNormalization object at 0x7f9ee64efc10>
# 130 : batchnormalization_39, <keras.layers.normalization.BatchNormalization object at 0x7f9ee64a5610>
# 131 : batchnormalization_40, <keras.layers.normalization.BatchNormalization object at 0x7f9ee63c6f90>
# 132 : mixed4, <keras.engine.topology.Merge object at 0x7f9ee639a6d0>
# 133 : convolution2d_45, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6335f90>
# 134 : convolution2d_45__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc190>
# 135 : batchnormalization_45, <keras.layers.normalization.BatchNormalization object at 0x7f9ee62cad50>
# 136 : convolution2d_46, <keras.layers.convolutional.Convolution2D object at 0x7f9ee628dcd0>
# 137 : convolution2d_46__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc9d0>
# 138 : batchnormalization_46, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6248a50>
# 139 : convolution2d_42, <keras.layers.convolutional.Convolution2D object at 0x7f9ee621f910>
# 140 : convolution2d_42__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcc90>
# 141 : convolution2d_47, <keras.layers.convolutional.Convolution2D object at 0x7f9ee61c6e50>
# 142 : convolution2d_47__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc910>
# 143 : batchnormalization_42, <keras.layers.normalization.BatchNormalization object at 0x7f9ee61b7f50>
# 144 : batchnormalization_47, <keras.layers.normalization.BatchNormalization object at 0x7f9ee615ae50>
# 145 : convolution2d_43, <keras.layers.convolutional.Convolution2D object at 0x7f9ee6129fd0>
# 146 : convolution2d_43__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc450>
# 147 : convolution2d_48, <keras.layers.convolutional.Convolution2D object at 0x7f9ee609ad50>
# 148 : convolution2d_48__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc7d0>
# 149 : batchnormalization_43, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6072bd0>
# 150 : batchnormalization_48, <keras.layers.normalization.BatchNormalization object at 0x7f9ee6019b10>
# 151 : averagepooling2d_5, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee5fe9f90>
# 152 : convolution2d_41, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5f55a10>
# 153 : convolution2d_41__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcad0>
# 154 : convolution2d_44, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5f06a90>
# 155 : convolution2d_44__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc4d0>
# 156 : convolution2d_49, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5f2fb10>
# 157 : convolution2d_49__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcfd0>
# 158 : convolution2d_50, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5ed5910>
# 159 : convolution2d_50__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcbd0>
# 160 : batchnormalization_41, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5ef8990>
# 161 : batchnormalization_44, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5e9e550>
# 162 : batchnormalization_49, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5e42b10>
# 163 : batchnormalization_50, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5ddd5d0>
# 164 : mixed5, <keras.engine.topology.Merge object at 0x7f9ee5db3bd0>
# 165 : convolution2d_55, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5d33550>
# 166 : convolution2d_55__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc950>
# 167 : batchnormalization_55, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5cf9350>
# 168 : convolution2d_56, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5ca47d0>
# 169 : convolution2d_56__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc510>
# 170 : batchnormalization_56, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5c5f8d0>
# 171 : convolution2d_52, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5c3df50>
# 172 : convolution2d_52__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc0d0>
# 173 : convolution2d_57, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5bf2410>
# 174 : convolution2d_57__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc090>
# 175 : batchnormalization_52, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5b60d10>
# 176 : batchnormalization_57, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5b07c90>
# 177 : convolution2d_53, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5b2c850>
# 178 : convolution2d_53__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfca10>
# 179 : convolution2d_58, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5aaf0d0>
# 180 : convolution2d_58__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc650>
# 181 : batchnormalization_53, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5a209d0>
# 182 : batchnormalization_58, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5a32b10>
# 183 : averagepooling2d_6, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee59ea510>
# 184 : convolution2d_51, <keras.layers.convolutional.Convolution2D object at 0x7f9ee596c890>
# 185 : convolution2d_51__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc310>
# 186 : convolution2d_54, <keras.layers.convolutional.Convolution2D object at 0x7f9ee591cf50>
# 187 : convolution2d_54__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfce90>
# 188 : convolution2d_59, <keras.layers.convolutional.Convolution2D object at 0x7f9ee58dba50>
# 189 : convolution2d_59__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc590>
# 190 : convolution2d_60, <keras.layers.convolutional.Convolution2D object at 0x7f9ee58ece10>
# 191 : convolution2d_60__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc2d0>
# 192 : batchnormalization_51, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5890c10>
# 193 : batchnormalization_54, <keras.layers.normalization.BatchNormalization object at 0x7f9ee58b6b50>
# 194 : batchnormalization_59, <keras.layers.normalization.BatchNormalization object at 0x7f9ee58715d0>
# 195 : batchnormalization_60, <keras.layers.normalization.BatchNormalization object at 0x7f9ee57dd890>
# 196 : mixed6, <keras.engine.topology.Merge object at 0x7f9ee5762690>
# 197 : convolution2d_65, <keras.layers.convolutional.Convolution2D object at 0x7f9ee56cf950>
# 198 : convolution2d_65__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcd90>
# 199 : batchnormalization_65, <keras.layers.normalization.BatchNormalization object at 0x7f9ee56fb490>
# 200 : convolution2d_66, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5640f90>
# 201 : convolution2d_66__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc5d0>
# 202 : batchnormalization_66, <keras.layers.normalization.BatchNormalization object at 0x7f9ee56782d0>
# 203 : convolution2d_62, <keras.layers.convolutional.Convolution2D object at 0x7f9ee55e8d50>
# 204 : convolution2d_62__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfca50>
# 205 : convolution2d_67, <keras.layers.convolutional.Convolution2D object at 0x7f9ee55a2b50>
# 206 : convolution2d_67__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc8d0>
# 207 : batchnormalization_62, <keras.layers.normalization.BatchNormalization object at 0x7f9ee557d950>
# 208 : batchnormalization_67, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5521790>
# 209 : convolution2d_63, <keras.layers.convolutional.Convolution2D object at 0x7f9ee54c7d50>
# 210 : convolution2d_63__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcb50>
# 211 : convolution2d_68, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5460810>
# 212 : convolution2d_68__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc810>
# 213 : batchnormalization_63, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5438890>
# 214 : batchnormalization_68, <keras.layers.normalization.BatchNormalization object at 0x7f9ee53dd450>
# 215 : averagepooling2d_7, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee5381a10>
# 216 : convolution2d_61, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5306290>
# 217 : convolution2d_61__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfccd0>
# 218 : convolution2d_64, <keras.layers.convolutional.Convolution2D object at 0x7f9ee52cce10>
# 219 : convolution2d_64__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc1d0>
# 220 : convolution2d_69, <keras.layers.convolutional.Convolution2D object at 0x7f9ee52f5e10>
# 221 : convolution2d_69__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc290>
# 222 : convolution2d_70, <keras.layers.convolutional.Convolution2D object at 0x7f9ee5298c10>
# 223 : convolution2d_70__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc490>
# 224 : batchnormalization_61, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5240a10>
# 225 : batchnormalization_64, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5251b50>
# 226 : batchnormalization_69, <keras.layers.normalization.BatchNormalization object at 0x7f9ee5209550>
# 227 : batchnormalization_70, <keras.layers.normalization.BatchNormalization object at 0x7f9ee51f8d90>
# 228 : mixed7, <keras.engine.topology.Merge object at 0x7f9ee5179610>
# 229 : convolution2d_73, <keras.layers.convolutional.Convolution2D object at 0x7f9ee50ebdd0>
# 230 : convolution2d_73__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc850>
# 231 : batchnormalization_73, <keras.layers.normalization.BatchNormalization object at 0x7f9ee50960d0>
# 232 : convolution2d_74, <keras.layers.convolutional.Convolution2D object at 0x7f9ee506dc10>
# 233 : convolution2d_74__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc250>
# 234 : batchnormalization_74, <keras.layers.normalization.BatchNormalization object at 0x7f9ee502aa10>
# 235 : convolution2d_71, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4f81850>
# 236 : convolution2d_71__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfca90>
# 237 : convolution2d_75, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4fbc190>
# 238 : convolution2d_75__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc890>
# 239 : batchnormalization_71, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4f16e10>
# 240 : batchnormalization_75, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4f38d90>
# 241 : convolution2d_72, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4ef1810>
# 242 : convolution2d_72__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcc50>
# 243 : convolution2d_76, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4e77d10>
# 244 : convolution2d_76__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcd10>
# 245 : batchnormalization_72, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4dd2b10>
# 246 : batchnormalization_76, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4dfa950>
# 247 : averagepooling2d_8, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee4db04d0>
# 248 : mixed8, <keras.engine.topology.Merge object at 0x7f9ee4d339d0>
# 249 : convolution2d_81, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4ccdfd0>
# 250 : convolution2d_81__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcf90>
# 251 : batchnormalization_81, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4cfcad0>
# 252 : convolution2d_78, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4c90f90>
# 253 : convolution2d_78__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc750>
# 254 : convolution2d_82, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4c4a390>
# 255 : convolution2d_82__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc990>
# 256 : batchnormalization_78, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4c39c90>
# 257 : batchnormalization_82, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4bd3c10>
# 258 : convolution2d_79, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4b827d0>
# 259 : convolution2d_79__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcf50>
# 260 : convolution2d_80, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4b06050>
# 261 : convolution2d_80__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc550>
# 262 : convolution2d_83, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4af4950>
# 263 : convolution2d_83__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc790>
# 264 : convolution2d_84, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4a88e10>
# 265 : convolution2d_84__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfc150>
# 266 : averagepooling2d_9, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee4aaac50>
# 267 : convolution2d_77, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4a50a50>
# 268 : convolution2d_77__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcdd0>
# 269 : batchnormalization_79, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4a61e90>
# 270 : batchnormalization_80, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4a78c10>
# 271 : batchnormalization_83, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4a2f690>
# 272 : batchnormalization_84, <keras.layers.normalization.BatchNormalization object at 0x7f9ee499d950>
# 273 : convolution2d_85, <keras.layers.convolutional.Convolution2D object at 0x7f9ee491d750>
# 274 : convolution2d_85__activation__, <keras.layers.core.Activation object at 0x7f9ee7dfcb90>
# 275 : batchnormalization_77, <keras.layers.normalization.BatchNormalization object at 0x7f9ee48a4c50>
# 276 : mixed9_0, <keras.engine.topology.Merge object at 0x7f9ee487fa90>
# 277 : merge_1, <keras.engine.topology.Merge object at 0x7f9ee4835610>
# 278 : batchnormalization_85, <keras.layers.normalization.BatchNormalization object at 0x7f9ee47cce10>
# 279 : mixed9, <keras.engine.topology.Merge object at 0x7f9ee47e5f50>
# 280 : convolution2d_90, <keras.layers.convolutional.Convolution2D object at 0x7f9ee47bc510>
# 281 : convolution2d_90__activation__, <keras.layers.core.Activation object at 0x7f9eb8078e10>
# 282 : batchnormalization_90, <keras.layers.normalization.BatchNormalization object at 0x7f9ee47511d0>
# 283 : convolution2d_87, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4728d90>
# 284 : convolution2d_87__activation__, <keras.layers.core.Activation object at 0x7f9eb8078e90>
# 285 : convolution2d_91, <keras.layers.convolutional.Convolution2D object at 0x7f9ee46e4b90>
# 286 : convolution2d_91__activation__, <keras.layers.core.Activation object at 0x7f9eb8078850>
# 287 : batchnormalization_87, <keras.layers.normalization.BatchNormalization object at 0x7f9ee46bd990>
# 288 : batchnormalization_91, <keras.layers.normalization.BatchNormalization object at 0x7f9ee46617d0>
# 289 : convolution2d_88, <keras.layers.convolutional.Convolution2D object at 0x7f9ee4607d90>
# 290 : convolution2d_88__activation__, <keras.layers.core.Activation object at 0x7f9eb8078dd0>
# 291 : convolution2d_89, <keras.layers.convolutional.Convolution2D object at 0x7f9ee45a0850>
# 292 : convolution2d_89__activation__, <keras.layers.core.Activation object at 0x7f9eb8078b90>
# 293 : convolution2d_92, <keras.layers.convolutional.Convolution2D object at 0x7f9ee45788d0>
# 294 : convolution2d_92__activation__, <keras.layers.core.Activation object at 0x7f9eb8078ed0>
# 295 : convolution2d_93, <keras.layers.convolutional.Convolution2D object at 0x7f9ee451dd10>
# 296 : convolution2d_93__activation__, <keras.layers.core.Activation object at 0x7f9eb8078a50>
# 297 : averagepooling2d_10, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee44c2b10>
# 298 : convolution2d_86, <keras.layers.convolutional.Convolution2D object at 0x7f9ee44eaa50>
# 299 : convolution2d_86__activation__, <keras.layers.core.Activation object at 0x7f9eb8078c10>
# 300 : batchnormalization_88, <keras.layers.normalization.BatchNormalization object at 0x7f9ee44f9550>
# 301 : batchnormalization_89, <keras.layers.normalization.BatchNormalization object at 0x7f9ee448cb10>
# 302 : batchnormalization_92, <keras.layers.normalization.BatchNormalization object at 0x7f9ee44b16d0>
# 303 : batchnormalization_93, <keras.layers.normalization.BatchNormalization object at 0x7f9ee44364d0>
# 304 : convolution2d_94, <keras.layers.convolutional.Convolution2D object at 0x7f9ee43a3790>
# 305 : convolution2d_94__activation__, <keras.layers.core.Activation object at 0x7f9eb8078c50>
# 306 : batchnormalization_86, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4327110>
# 307 : mixed9_1, <keras.engine.topology.Merge object at 0x7f9ee4281390>
# 308 : merge_2, <keras.engine.topology.Merge object at 0x7f9ee42b8650>
# 309 : batchnormalization_94, <keras.layers.normalization.BatchNormalization object at 0x7f9ee4253310>
# 310 : mixed10, <keras.engine.topology.Merge object at 0x7f9ee427e890>
# 311 : averagepooling2d_11, <keras.layers.pooling.AveragePooling2D object at 0x7f9ee423b5d0>
# 312 : flatten_1, <keras.layers.core.Flatten object at 0x7f9ee419a890>
# 313 : dense_1, <keras.layers.core.Dense object at 0x7f9ee41ab490>
# 314 : dense_1__activation__, <keras.layers.core.Activation object at 0x7f9eb8078c90>

# %% [markdown]
# ## Add metadata

# %%
coreml_model.author = 'Udacity'
coreml_model.license = 'MIT'
coreml_model.short_description = 'Classifies food from an image as one of 101 classes'
coreml_model.input_description['image'] = 'Food image'
coreml_model.output_description['confidence'] = 'Confidence of the food classification'
coreml_model.output_description['classLabel'] = 'Food classification label'

# %% [markdown]
# ## Inspect Core ML model

# %%
coreml_model
# Out:
# input {
#   name: "image"
#   shortDescription: "Food image"
#   type {
#     imageType {
#       width: 299
#       height: 299
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "confidence"
#   shortDescription: "Confidence of the food classification"
#   type {
#     dictionaryType {
#       stringKeyType {
#       }
#     }
#   }
# }
# output {
#   name: "classLabel"
#   shortDescription: "Food classification label"
#   type {
#     stringType {
#     }
#   }
# }
# predictedFeatureName: "classLabel"
# predictedProbabilitiesName: "confidence"
# metadata {
#   shortDescription: "Classifies food from an image as one of 101 classes"
#   author: "Udacity"
#   license: "MIT"
# }

# %% [markdown]
# ## Test Core ML Model Predictions

# %%
from PIL import Image

# %%
bibimbap = Image.open('bibimbap.jpg')

# %%
bibimbap.show()

# %%
coreml_model.predict({'image' : bibimbap})
# Out:
# {u'classLabel': u'bibimbap',
#  u'confidence': {u'apple_pie': 6.411606136680348e-06,
#   u'baby_back_ribs': 1.9007397611403576e-07,
#   u'baklava': 6.982965032875654e-07,
#   u'beef_carpaccio': 4.48674518338521e-06,
#   u'beef_tartare': 0.013760291039943695,
#   u'beet_salad': 4.624263056030031e-06,
#   u'beignets': 6.485367975983536e-07,
#   u'bibimbap': 0.980607271194458,
#   u'bread_pudding': 4.4046614675608e-06,
#   u'breakfast_burrito': 2.538227183990216e-09,
#   u'bruschetta': 1.177120225293038e-06,
#   u'caesar_salad': 2.0071544781785633e-07,
#   u'cannoli': 1.2305112306876254e-07,
#   u'caprese_salad': 1.7964309506623977e-07,
#   u'carrot_cake': 2.857279241652577e-06,
#   u'ceviche': 4.1571220208425075e-06,
#   u'cheese_plate': 5.047463491791859e-05,
#   u'cheesecake': 3.4329343634453835e-07,
#   u'chicken_curry': 5.922272066527512e-06,
#   u'chicken_quesadilla': 2.4410649501760417e-08,
#   u'chicken_wings': 4.871037617704133e-07,
#   u'chocolate_cake': 4.253855422575725e-06,
#   u'chocolate_mousse': 5.9264450101181865e-05,
#   u'churros': 1.974442653818187e-07,
#   u'clam_chowder': 3.6968550443106096e-09,
#   u'club_sandwich': 2.8940382890141336e-06,
#   u'crab_cakes': 4.519650246948004e-06,
#   u'creme_brulee': 1.5726767514934181e-06,
#   u'croque_madame': 5.367521680454956e-07,
#   u'cup_cakes': 2.0031999156344682e-05,
#   u'deviled_eggs': 5.390621140577423e-07,
#   u'donuts': 3.6582102325155574e-07,
#   u'dumplings': 7.530580887760152e-07,
#   u'edamame': 1.5205236195470206e-05,
#   u'eggs_benedict': 1.6883198838968383e-07,
#   u'escargots': 3.9491018810622336e-07,
#   u'falafel': 4.337719872182788e-07,
#   u'filet_mignon': 8.298654847749276e-07,
#   u'fish_and_chips': 5.07406127780996e-07,
#   u'foie_gras': 3.1820975436858134e-06,
#   u'french_fries': 9.221276968673919e-07,
#   u'french_onion_soup': 2.8297087339979043e-08,
#   u'french_toast': 5.505905775748943e-08,
#   u'fried_calamari': 4.9266354835708626e-06,
#   u'fried_rice': 0.0009052858222275972,
#   u'frozen_yogurt': 4.426154191605747e-06,
#   u'garlic_bread': 1.9007623919264915e-08,
#   u'gnocchi': 6.054498953744769e-06,
#   u'greek_salad': 8.364048653675127e-08,
#   u'grilled_cheese_sandwich': 1.9101937809296032e-08,
#   u'grilled_salmon': 1.1646352504612878e-06,
#   u'guacamole': 4.972833878014171e-08,
#   u'gyoza': 3.204615239837949e-08,
#   u'hamburger': 4.268179964128649e-06,
#   u'hot_and_sour_soup': 4.808827611668676e-07,
#   u'hot_dog': 9.154962867796712e-07,
#   u'huevos_rancheros': 7.03277791558321e-08,
#   u'hummus': 2.6137493591704697e-07,
#   u'ice_cream': 3.419405629756511e-06,
#   u'lasagna': 7.188164090621285e-07,
#   u'lobster_bisque': 2.254308100191338e-07,
#   u'lobster_roll_sandwich': 1.2811983651772607e-07,
#   u'macaroni_and_cheese': 5.249752348390757e-07,
#   u'macarons': 3.708497388288379e-05,
#   u'miso_soup': 1.2402609854689217e-06,
#   u'mussels': 2.3927800612000283e-06,
#   u'nachos': 8.115721925605612e-07,
#   u'omelette': 4.678214793329971e-08,
#   u'onion_rings': 1.3657300712566212e-07,
#   u'oysters': 4.531004833552288e-06,
#   u'pad_thai': 1.7340367776341736e-05,
#   u'paella': 0.00032894706237129867,
#   u'pancakes': 1.2590480480412225e-07,
#   u'panna_cotta': 1.6181291357497685e-05,
#   u'peking_duck': 2.0189006590953795e-06,
#   u'pho': 1.5784624451953277e-07,
#   u'pizza': 6.08239290045276e-08,
#   u'pork_chop': 3.480050281723379e-06,
#   u'poutine': 9.65412073128391e-06,
#   u'prime_rib': 1.0854269021365326e-06,
#   u'pulled_pork_sandwich': 1.4599296264350414e-05,
#   u'ramen': 1.8717571947490796e-05,
#   u'ravioli': 4.0489911157237657e-07,
#   u'red_velvet_cake': 7.077690497681033e-06,
#   u'risotto': 0.000118320356705226,
#   u'samosa': 4.850867867389752e-07,
#   u'sashimi': 2.1035389181633946e-06,
#   u'scallops': 2.142272933269851e-05,
#   u'seaweed_salad': 1.8850221749744378e-05,
#   u'shrimp_and_grits': 5.61428862511093e-07,
#   u'spaghetti_bolognese': 0.0037129814736545086,
#   u'spaghetti_carbonara': 4.290226934244856e-05,
#   u'spring_rolls': 1.830147624559686e-07,
#   u'steak': 1.595640128471132e-06,
#   u'strawberry_shortcake': 6.430000667023705e-06,
#   u'sushi': 1.5559800203845953e-06,
#   u'tacos': 3.0107460702311073e-07,
#   u'takoyaki': 4.389002299376443e-07,
#   u'tiramisu': 2.468621914886171e-06,
#   u'tuna_tartare': 9.805875015445054e-05,
#   u'waffles': 7.677701887587318e-07}}

# %% [markdown]
# ## Save to .mlmodel

# %%
coreml_model.save('Food101Net.mlmodel')
